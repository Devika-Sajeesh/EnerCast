# %% [markdown]
# # 01 - Data Exploration
#
# This notebook explores the raw energy consumption and CO2 emissions data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
