# %% [markdown]
# # 03 - Feature Engineering
#
# This notebook handles feature engineering for the ML models.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
